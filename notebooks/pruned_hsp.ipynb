# %% [markdown]
# So what I have is the integrated gradients up to the ESSP.
#
# What I don't have is a reliable HSP index.
#
# One thing I could do is just try different indices near my current HSP index at a lower temparture and see if I can reliably get an accuracy above 0.5
#
# If I do that, and find an index that reliably gets above 0.5, then I just need to check when I prune the cot steps.
#
# But I need a visualization for this.
#
# Should I prune the lowest importance sentence one at a time like how I did for the greedy backward elimination?
